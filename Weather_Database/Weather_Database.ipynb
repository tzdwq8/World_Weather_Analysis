# %%
# Import the dependencies
import pandas as pd
import numpy as np
import requests
from config import weather_api_key

# %%
# Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 770

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | haverfordwest
# Processing Record 6 of Set 1 | thinadhoo
# Processing Record 7 of Set 1 | benguela
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | tasiilaq
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | verkhnyaya maksakovka
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | batagay-alyta
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | coihaique
# Processing Record 16 of Set 1 | dikson
# Processing Record 17 of Set 1 | bahua
# Processing Record 18 of Set 1 | saint-philippe
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | bengkulu
# Processing Record 22 of Set 1 | reconquista
# Processing Record 23 of Set 1 | lagoa
# Processing Record 24 of Set 1 | provideniya
# Processing Record 25 of Set 1 | ruatoria
# City not found. Skipping...
# Processing Record 26 of Set 1 | de-kastri
# Processing Record 27 of Set 1 | aswan
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 1 | sitangkai
# Processing Record 31 of Set 1 | castro
# Processing Record 32 of Set 1 | port elizabeth
# Processing Record 33 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 1 | arraial do cabo
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | kupang
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | nizhneudinsk
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 1 | aklavik
# Processing Record 42 of Set 1 | rancho palos verdes
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | tuktoyaktuk
# Processing Record 45 of Set 1 | bambous virieux
# Processing Record 46 of Set 1 | nanortalik
# Processing Record 47 of Set 1 | front royal
# Processing Record 48 of Set 1 | upernavik
# Processing Record 49 of Set 1 | atar
# Processing Record 50 of Set 1 | dawlatabad
# Processing Record 1 of Set 2 | kloulklubed
# Processing Record 2 of Set 2 | chokurdakh
# Processing Record 3 of Set 2 | akyab
# Processing Record 4 of Set 2 | biloela
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | asfi
# Processing Record 7 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 2 | margate
# Processing Record 10 of Set 2 | mar del plata
# Processing Record 11 of Set 2 | faanui
# Processing Record 12 of Set 2 | hithadhoo
# Processing Record 13 of Set 2 | bluff
# Processing Record 14 of Set 2 | aktau
# Processing Record 15 of Set 2 | ludvika
# Processing Record 16 of Set 2 | thompson
# Processing Record 17 of Set 2 | nome
# Processing Record 18 of Set 2 | petropavl
# Processing Record 19 of Set 2 | barrow
# Processing Record 20 of Set 2 | lompoc
# Processing Record 21 of Set 2 | yenagoa
# Processing Record 22 of Set 2 | nyurba
# Processing Record 23 of Set 2 | yumen
# Processing Record 24 of Set 2 | rovaniemi
# Processing Record 25 of Set 2 | carnarvon
# Processing Record 26 of Set 2 | aksu
# Processing Record 27 of Set 2 | east london
# Processing Record 28 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 2 | neyshabur
# Processing Record 30 of Set 2 | ostrovnoy
# Processing Record 31 of Set 2 | kavaratti
# Processing Record 32 of Set 2 | san patricio
# Processing Record 33 of Set 2 | orlik
# Processing Record 34 of Set 2 | namatanai
# Processing Record 35 of Set 2 | chuy
# Processing Record 36 of Set 2 | nishihara
# Processing Record 37 of Set 2 | khatanga
# Processing Record 38 of Set 2 | cape town
# Processing Record 39 of Set 2 | olafsvik
# Processing Record 40 of Set 2 | vila velha
# Processing Record 41 of Set 2 | port alfred
# Processing Record 42 of Set 2 | souillac
# Processing Record 43 of Set 2 | codrington
# Processing Record 44 of Set 2 | nauta
# Processing Record 45 of Set 2 | nikolskoye
# Processing Record 46 of Set 2 | mahebourg
# Processing Record 47 of Set 2 | saskylakh
# Processing Record 48 of Set 2 | nizwa
# Processing Record 49 of Set 2 | portland
# Processing Record 50 of Set 2 | bilma
# Processing Record 1 of Set 3 | yar-sale
# Processing Record 2 of Set 3 | new norfolk
# Processing Record 3 of Set 3 | odweyne
# Processing Record 4 of Set 3 | sitka
# Processing Record 5 of Set 3 | galiwinku
# City not found. Skipping...
# Processing Record 6 of Set 3 | caxito
# Processing Record 7 of Set 3 | cherskiy
# Processing Record 8 of Set 3 | mayo
# Processing Record 9 of Set 3 | clyde river
# Processing Record 10 of Set 3 | algeciras
# Processing Record 11 of Set 3 | slave lake
# Processing Record 12 of Set 3 | veshenskaya
# Processing Record 13 of Set 3 | buin
# Processing Record 14 of Set 3 | saint-leu
# Processing Record 15 of Set 3 | ponta do sol
# Processing Record 16 of Set 3 | banihal
# Processing Record 17 of Set 3 | ilulissat
# Processing Record 18 of Set 3 | kodiak
# Processing Record 19 of Set 3 | sinfra
# Processing Record 20 of Set 3 | kavieng
# Processing Record 21 of Set 3 | lapua
# Processing Record 22 of Set 3 | port blair
# Processing Record 23 of Set 3 | messina
# Processing Record 24 of Set 3 | benjamin constant
# Processing Record 25 of Set 3 | lebu
# Processing Record 26 of Set 3 | linoan
# Processing Record 27 of Set 3 | hasaki
# Processing Record 28 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 3 | latung
# Processing Record 30 of Set 3 | road town
# Processing Record 31 of Set 3 | tiksi
# Processing Record 32 of Set 3 | ferkessedougou
# Processing Record 33 of Set 3 | gayny
# Processing Record 34 of Set 3 | okhotsk
# Processing Record 35 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 3 | agirish
# Processing Record 37 of Set 3 | ulaanbaatar
# Processing Record 38 of Set 3 | marsh harbour
# Processing Record 39 of Set 3 | abnub
# Processing Record 40 of Set 3 | nouadhibou
# Processing Record 41 of Set 3 | avarua
# Processing Record 42 of Set 3 | cabo san lucas
# Processing Record 43 of Set 3 | hirara
# Processing Record 44 of Set 3 | cabedelo
# Processing Record 45 of Set 3 | itamaraju
# Processing Record 46 of Set 3 | atuona
# Processing Record 47 of Set 3 | bredy
# Processing Record 48 of Set 3 | puerto ayora
# Processing Record 49 of Set 3 | tongchuan
# Processing Record 50 of Set 3 | vidim
# Processing Record 1 of Set 4 | dauphin
# Processing Record 2 of Set 4 | padang
# Processing Record 3 of Set 4 | saldanha
# Processing Record 4 of Set 4 | mareeba
# Processing Record 5 of Set 4 | teya
# Processing Record 6 of Set 4 | yulara
# Processing Record 7 of Set 4 | batsfjord
# Processing Record 8 of Set 4 | ouesso
# Processing Record 9 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 4 | bud
# Processing Record 11 of Set 4 | antalaha
# Processing Record 12 of Set 4 | terrace
# Processing Record 13 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 14 of Set 4 | x-can
# City not found. Skipping...
# Processing Record 15 of Set 4 | buraydah
# Processing Record 16 of Set 4 | alofi
# Processing Record 17 of Set 4 | te anau
# Processing Record 18 of Set 4 | ballina
# Processing Record 19 of Set 4 | camden
# Processing Record 20 of Set 4 | koutiala
# Processing Record 21 of Set 4 | genthin
# Processing Record 22 of Set 4 | zilair
# Processing Record 23 of Set 4 | kahului
# Processing Record 24 of Set 4 | san juan
# Processing Record 25 of Set 4 | los llanos de aridane
# Processing Record 26 of Set 4 | robertsport
# Processing Record 27 of Set 4 | kuching
# Processing Record 28 of Set 4 | nacala
# Processing Record 29 of Set 4 | sao filipe
# Processing Record 30 of Set 4 | torbay
# Processing Record 31 of Set 4 | camacha
# Processing Record 32 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 4 | moerai
# Processing Record 34 of Set 4 | bahia blanca
# Processing Record 35 of Set 4 | axim
# Processing Record 36 of Set 4 | matara
# Processing Record 37 of Set 4 | terracina
# Processing Record 38 of Set 4 | acarau
# Processing Record 39 of Set 4 | mehamn
# Processing Record 40 of Set 4 | leningradskiy
# Processing Record 41 of Set 4 | guasdualito
# Processing Record 42 of Set 4 | talnakh
# Processing Record 43 of Set 4 | damghan
# Processing Record 44 of Set 4 | ritchie
# Processing Record 45 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 46 of Set 4 | erenhot
# Processing Record 47 of Set 4 | kruisfontein
# Processing Record 48 of Set 4 | kapaa
# Processing Record 49 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 50 of Set 4 | senador jose porfirio
# Processing Record 1 of Set 5 | pontianak
# Processing Record 2 of Set 5 | dingle
# Processing Record 3 of Set 5 | surab
# Processing Record 4 of Set 5 | bela
# Processing Record 5 of Set 5 | tars
# Processing Record 6 of Set 5 | santa maria
# Processing Record 7 of Set 5 | baruun-urt
# Processing Record 8 of Set 5 | seoul
# Processing Record 9 of Set 5 | victoria
# Processing Record 10 of Set 5 | praia da vitoria
# Processing Record 11 of Set 5 | mount gambier
# Processing Record 12 of Set 5 | tooele
# Processing Record 13 of Set 5 | srednekolymsk
# Processing Record 14 of Set 5 | qingdao
# Processing Record 15 of Set 5 | gat
# Processing Record 16 of Set 5 | waterloo
# Processing Record 17 of Set 5 | bairnsdale
# Processing Record 18 of Set 5 | whitehorse
# Processing Record 19 of Set 5 | red bluff
# Processing Record 20 of Set 5 | sakaraha
# Processing Record 21 of Set 5 | port macquarie
# Processing Record 22 of Set 5 | turukhansk
# Processing Record 23 of Set 5 | borzya
# Processing Record 24 of Set 5 | tura
# Processing Record 25 of Set 5 | biak
# Processing Record 26 of Set 5 | flinders
# Processing Record 27 of Set 5 | champerico
# Processing Record 28 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 29 of Set 5 | sangerhausen
# Processing Record 30 of Set 5 | mogadishu
# Processing Record 31 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 32 of Set 5 | tammisaari
# Processing Record 33 of Set 5 | mitu
# Processing Record 34 of Set 5 | nerchinskiy zavod
# Processing Record 35 of Set 5 | pacific grove
# Processing Record 36 of Set 5 | yantai
# Processing Record 37 of Set 5 | vizinga
# Processing Record 38 of Set 5 | sept-iles
# Processing Record 39 of Set 5 | esil
# Processing Record 40 of Set 5 | severo-kurilsk
# Processing Record 41 of Set 5 | kollam
# Processing Record 42 of Set 5 | butaritari
# Processing Record 43 of Set 5 | mezen
# Processing Record 44 of Set 5 | port hardy
# Processing Record 45 of Set 5 | asau
# Processing Record 46 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 5 | lianyuan
# Processing Record 48 of Set 5 | salinas
# Processing Record 49 of Set 5 | zabolotovka
# Processing Record 50 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 1 of Set 6 | invermere
# Processing Record 2 of Set 6 | horadiz
# Processing Record 3 of Set 6 | minab
# Processing Record 4 of Set 6 | ojinaga
# Processing Record 5 of Set 6 | college
# Processing Record 6 of Set 6 | riyadh
# Processing Record 7 of Set 6 | broken hill
# Processing Record 8 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 6 | puerto maldonado
# Processing Record 10 of Set 6 | arrecife
# Processing Record 11 of Set 6 | emba
# Processing Record 12 of Set 6 | hambantota
# Processing Record 13 of Set 6 | taltal
# Processing Record 14 of Set 6 | constitucion
# Processing Record 15 of Set 6 | archidona
# Processing Record 16 of Set 6 | katsuura
# Processing Record 17 of Set 6 | novoagansk
# Processing Record 18 of Set 6 | rexburg
# Processing Record 19 of Set 6 | princeton
# Processing Record 20 of Set 6 | san cristobal
# Processing Record 21 of Set 6 | parana
# Processing Record 22 of Set 6 | kanniyakumari
# Processing Record 23 of Set 6 | bull savanna
# Processing Record 24 of Set 6 | georgetown
# Processing Record 25 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 26 of Set 6 | luba
# Processing Record 27 of Set 6 | half moon bay
# Processing Record 28 of Set 6 | rio gallegos
# Processing Record 29 of Set 6 | iquitos
# Processing Record 30 of Set 6 | xuanzhou
# Processing Record 31 of Set 6 | nelson bay
# Processing Record 32 of Set 6 | birao
# Processing Record 33 of Set 6 | aurora
# Processing Record 34 of Set 6 | seda
# Processing Record 35 of Set 6 | araouane
# Processing Record 36 of Set 6 | armacao dos buzios
# City not found. Skipping...
# Processing Record 37 of Set 6 | rusera
# Processing Record 38 of Set 6 | wasilla
# Processing Record 39 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 6 | chifeng
# Processing Record 41 of Set 6 | kidal
# Processing Record 42 of Set 6 | tecoanapa
# Processing Record 43 of Set 6 | esperance
# Processing Record 44 of Set 6 | anuchino
# Processing Record 45 of Set 6 | margherita di savoia
# Processing Record 46 of Set 6 | vanimo
# Processing Record 47 of Set 6 | roma
# Processing Record 48 of Set 6 | honggang
# Processing Record 49 of Set 6 | hilo
# Processing Record 50 of Set 6 | semey
# Processing Record 1 of Set 7 | pong
# Processing Record 2 of Set 7 | pisco
# Processing Record 3 of Set 7 | fortuna
# Processing Record 4 of Set 7 | ketchikan
# Processing Record 5 of Set 7 | novo oriente
# Processing Record 6 of Set 7 | oranjemund
# Processing Record 7 of Set 7 | zhenhai
# Processing Record 8 of Set 7 | nguru
# Processing Record 9 of Set 7 | lavrentiya
# Processing Record 10 of Set 7 | richards bay
# Processing Record 11 of Set 7 | enshi
# Processing Record 12 of Set 7 | oyem
# Processing Record 13 of Set 7 | juegang
# Processing Record 14 of Set 7 | bintulu
# Processing Record 15 of Set 7 | aktas
# Processing Record 16 of Set 7 | saint george
# Processing Record 17 of Set 7 | haines junction
# Processing Record 18 of Set 7 | juybar
# Processing Record 19 of Set 7 | isangel
# Processing Record 20 of Set 7 | berlevag
# Processing Record 21 of Set 7 | guaruja
# Processing Record 22 of Set 7 | chumikan
# Processing Record 23 of Set 7 | mahajanga
# Processing Record 24 of Set 7 | malangali
# Processing Record 25 of Set 7 | naze
# Processing Record 26 of Set 7 | lawan kuda baharu
# City not found. Skipping...
# Processing Record 27 of Set 7 | batangafo
# Processing Record 28 of Set 7 | toamasina
# Processing Record 29 of Set 7 | lannion
# Processing Record 30 of Set 7 | pevek
# Processing Record 31 of Set 7 | honningsvag
# Processing Record 32 of Set 7 | north bend
# Processing Record 33 of Set 7 | antofagasta
# Processing Record 34 of Set 7 | byron bay
# Processing Record 35 of Set 7 | la romana
# Processing Record 36 of Set 7 | la paz
# Processing Record 37 of Set 7 | panacan
# Processing Record 38 of Set 7 | muisne
# Processing Record 39 of Set 7 | buala
# Processing Record 40 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 7 | trenggalek
# Processing Record 42 of Set 7 | ucluelet
# Processing Record 43 of Set 7 | creel
# Processing Record 44 of Set 7 | sosua
# Processing Record 45 of Set 7 | baiquan
# Processing Record 46 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 47 of Set 7 | mapiripan
# Processing Record 48 of Set 7 | sioux lookout
# Processing Record 49 of Set 7 | nemuro
# Processing Record 50 of Set 7 | erdenet
# Processing Record 1 of Set 8 | baoning
# Processing Record 2 of Set 8 | ambatondrazaka
# Processing Record 3 of Set 8 | najran
# Processing Record 4 of Set 8 | bathsheba
# Processing Record 5 of Set 8 | aramil
# Processing Record 6 of Set 8 | parry sound
# Processing Record 7 of Set 8 | beringovskiy
# Processing Record 8 of Set 8 | noshiro
# Processing Record 9 of Set 8 | tafresh
# Processing Record 10 of Set 8 | shellbrook
# Processing Record 11 of Set 8 | ileza
# Processing Record 12 of Set 8 | ixtapa
# Processing Record 13 of Set 8 | sunrise manor
# Processing Record 14 of Set 8 | oulainen
# Processing Record 15 of Set 8 | salalah
# Processing Record 16 of Set 8 | saint-francois
# Processing Record 17 of Set 8 | monrovia
# Processing Record 18 of Set 8 | bima
# Processing Record 19 of Set 8 | wajir
# Processing Record 20 of Set 8 | bogale
# Processing Record 21 of Set 8 | languyan
# Processing Record 22 of Set 8 | sobolevo
# Processing Record 23 of Set 8 | mangaratiba
# Processing Record 24 of Set 8 | samarai
# Processing Record 25 of Set 8 | northam
# Processing Record 26 of Set 8 | kutina
# Processing Record 27 of Set 8 | huoqiu
# Processing Record 28 of Set 8 | shache
# Processing Record 29 of Set 8 | dakar
# Processing Record 30 of Set 8 | blythe
# Processing Record 31 of Set 8 | forbes
# Processing Record 32 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 8 | nan
# Processing Record 34 of Set 8 | nipawin
# Processing Record 35 of Set 8 | praxedis guerrero
# Processing Record 36 of Set 8 | ahipara
# Processing Record 37 of Set 8 | kalangala
# Processing Record 38 of Set 8 | talcahuano
# Processing Record 39 of Set 8 | leshukonskoye
# Processing Record 40 of Set 8 | garowe
# Processing Record 41 of Set 8 | amot
# Processing Record 42 of Set 8 | omsukchan
# Processing Record 43 of Set 8 | auki
# Processing Record 44 of Set 8 | atyrau
# Processing Record 45 of Set 8 | bandarbeyla
# Processing Record 46 of Set 8 | coahuayana
# Processing Record 47 of Set 8 | ayna
# Processing Record 48 of Set 8 | udachnyy
# Processing Record 49 of Set 8 | imbituba
# Processing Record 50 of Set 8 | nantucket
# Processing Record 1 of Set 9 | sampang
# Processing Record 2 of Set 9 | surt
# Processing Record 3 of Set 9 | muros
# Processing Record 4 of Set 9 | jiayuguan
# Processing Record 5 of Set 9 | vestmannaeyjar
# Processing Record 6 of Set 9 | pemba
# Processing Record 7 of Set 9 | zonguldak
# Processing Record 8 of Set 9 | faya
# Processing Record 9 of Set 9 | yaan
# Processing Record 10 of Set 9 | sao joao da barra
# Processing Record 11 of Set 9 | marsa matruh
# Processing Record 12 of Set 9 | burica
# City not found. Skipping...
# Processing Record 13 of Set 9 | namibe
# Processing Record 14 of Set 9 | tottori
# Processing Record 15 of Set 9 | mandalgovi
# Processing Record 16 of Set 9 | niono
# Processing Record 17 of Set 9 | ust-kuyga
# Processing Record 18 of Set 9 | laguna
# Processing Record 19 of Set 9 | raigarh
# Processing Record 20 of Set 9 | umm lajj
# Processing Record 21 of Set 9 | shimoda
# Processing Record 22 of Set 9 | katherine
# Processing Record 23 of Set 9 | tuatapere
# Processing Record 24 of Set 9 | montrose
# Processing Record 25 of Set 9 | nabire
# Processing Record 26 of Set 9 | husavik
# Processing Record 27 of Set 9 | kudahuvadhoo
# Processing Record 28 of Set 9 | yerbogachen
# Processing Record 29 of Set 9 | verkhoyansk
# Processing Record 30 of Set 9 | kabinda
# Processing Record 31 of Set 9 | chegdomyn
# Processing Record 32 of Set 9 | emerald
# Processing Record 33 of Set 9 | airai
# Processing Record 34 of Set 9 | beira
# Processing Record 35 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 36 of Set 9 | vila franca do campo
# Processing Record 37 of Set 9 | deer lake
# Processing Record 38 of Set 9 | poya
# Processing Record 39 of Set 9 | dubai
# Processing Record 40 of Set 9 | port-cartier
# Processing Record 41 of Set 9 | salmon arm
# Processing Record 42 of Set 9 | cidreira
# Processing Record 43 of Set 9 | nichinan
# Processing Record 44 of Set 9 | longyearbyen
# Processing Record 45 of Set 9 | hovd
# Processing Record 46 of Set 9 | touros
# Processing Record 47 of Set 9 | ouango
# Processing Record 48 of Set 9 | pangai
# Processing Record 49 of Set 9 | alto vera
# City not found. Skipping...
# Processing Record 50 of Set 9 | san policarpo
# Processing Record 1 of Set 10 | kununurra
# Processing Record 2 of Set 10 | adiake
# Processing Record 3 of Set 10 | bolshiye uki
# City not found. Skipping...
# Processing Record 4 of Set 10 | estelle
# Processing Record 5 of Set 10 | mantua
# Processing Record 6 of Set 10 | vardo
# Processing Record 7 of Set 10 | rio blanco
# Processing Record 8 of Set 10 | lata
# Processing Record 9 of Set 10 | westport
# Processing Record 10 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 11 of Set 10 | sabha
# Processing Record 12 of Set 10 | viedma
# Processing Record 13 of Set 10 | ambilobe
# Processing Record 14 of Set 10 | toora-khem
# Processing Record 15 of Set 10 | isabela
# Processing Record 16 of Set 10 | vostok
# Processing Record 17 of Set 10 | volksrust
# Processing Record 18 of Set 10 | grindavik
# Processing Record 19 of Set 10 | ancud
# Processing Record 20 of Set 10 | port-gentil
# Processing Record 21 of Set 10 | ostersund
# Processing Record 22 of Set 10 | uruzgan
# Processing Record 23 of Set 10 | anadyr
# Processing Record 24 of Set 10 | gananoque
# Processing Record 25 of Set 10 | chapais
# Processing Record 26 of Set 10 | ust-nera
# Processing Record 27 of Set 10 | geraldton
# Processing Record 28 of Set 10 | ribeira grande
# Processing Record 29 of Set 10 | hallingby
# City not found. Skipping...
# Processing Record 30 of Set 10 | wewak
# Processing Record 31 of Set 10 | linxia
# Processing Record 32 of Set 10 | rondonopolis
# Processing Record 33 of Set 10 | sompeta
# Processing Record 34 of Set 10 | pyay
# Processing Record 35 of Set 10 | paveh
# Processing Record 36 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 10 | aloleng
# Processing Record 38 of Set 10 | taloqan
# Processing Record 39 of Set 10 | balaipungut
# Processing Record 40 of Set 10 | rudnogorsk
# Processing Record 41 of Set 10 | samfya
# Processing Record 42 of Set 10 | genhe
# Processing Record 43 of Set 10 | turbat
# Processing Record 44 of Set 10 | rolim de moura
# City not found. Skipping...
# Processing Record 45 of Set 10 | hobyo
# Processing Record 46 of Set 10 | mount isa
# Processing Record 47 of Set 10 | waddan
# Processing Record 48 of Set 10 | sorong
# Processing Record 49 of Set 10 | maceio
# Processing Record 50 of Set 10 | tortoli
# Processing Record 1 of Set 11 | temir
# Processing Record 2 of Set 11 | pasni
# Processing Record 3 of Set 11 | bolshoye kozino
# City not found. Skipping...
# Processing Record 4 of Set 11 | borovoy
# Processing Record 5 of Set 11 | guerrero negro
# Processing Record 6 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 11 | arvin
# Processing Record 8 of Set 11 | olinda
# Processing Record 9 of Set 11 | poum
# Processing Record 10 of Set 11 | adrar
# Processing Record 11 of Set 11 | cabo rojo
# Processing Record 12 of Set 11 | nuuk
# Processing Record 13 of Set 11 | urbano santos
# Processing Record 14 of Set 11 | huicungo
# Processing Record 15 of Set 11 | shaunavon
# Processing Record 16 of Set 11 | nhulunbuy
# Processing Record 17 of Set 11 | lorengau
# Processing Record 18 of Set 11 | hvide sande
# Processing Record 19 of Set 11 | calatayud
# Processing Record 20 of Set 11 | hollins
# Processing Record 21 of Set 11 | koumac
# Processing Record 22 of Set 11 | taksimo
# Processing Record 23 of Set 11 | villa carlos paz
# Processing Record 24 of Set 11 | narsaq
# Processing Record 25 of Set 11 | teknaf
# Processing Record 26 of Set 11 | noumea
# Processing Record 27 of Set 11 | russell
# Processing Record 28 of Set 11 | tekkalakota
# City not found. Skipping...
# Processing Record 29 of Set 11 | victoria point
# Processing Record 30 of Set 11 | zhigansk
# Processing Record 31 of Set 11 | labuhan
# Processing Record 32 of Set 11 | guiyang
# Processing Record 33 of Set 11 | zeya
# Processing Record 34 of Set 11 | pangnirtung
# Processing Record 35 of Set 11 | san quintin
# Processing Record 36 of Set 11 | tuytepa
# Processing Record 37 of Set 11 | sault sainte marie
# Processing Record 38 of Set 11 | deputatskiy
# Processing Record 39 of Set 11 | zaysan
# Processing Record 40 of Set 11 | nara
# Processing Record 41 of Set 11 | uray
# Processing Record 42 of Set 11 | forestville
# Processing Record 43 of Set 11 | mbour
# Processing Record 44 of Set 11 | bobo dioulasso
# Processing Record 45 of Set 11 | osakarovka
# Processing Record 46 of Set 11 | moree
# Processing Record 47 of Set 11 | auray
# Processing Record 48 of Set 11 | luderitz
# Processing Record 49 of Set 11 | dabhol
# Processing Record 50 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 12 | mamallapuram
# Processing Record 2 of Set 12 | salinopolis
# Processing Record 3 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 4 of Set 12 | abu samrah
# Processing Record 5 of Set 12 | dingzhou
# Processing Record 6 of Set 12 | hualmay
# Processing Record 7 of Set 12 | den helder
# Processing Record 8 of Set 12 | mocajuba
# Processing Record 9 of Set 12 | ous
# Processing Record 10 of Set 12 | chesma
# Processing Record 11 of Set 12 | milingimbi
# City not found. Skipping...
# Processing Record 12 of Set 12 | timberlake
# Processing Record 13 of Set 12 | bagua grande
# Processing Record 14 of Set 12 | vanavara
# Processing Record 15 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 16 of Set 12 | comodoro rivadavia
# Processing Record 17 of Set 12 | hirado
# Processing Record 18 of Set 12 | coatepec harinas
# Processing Record 19 of Set 12 | puerto del rosario
# Processing Record 20 of Set 12 | lakselv
# Processing Record 21 of Set 12 | tiznit
# Processing Record 22 of Set 12 | portobelo
# Processing Record 23 of Set 12 | bonavista
# Processing Record 24 of Set 12 | norman wells
# Processing Record 25 of Set 12 | zhaotong
# Processing Record 26 of Set 12 | mitsamiouli
# Processing Record 27 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 28 of Set 12 | chambersburg
# Processing Record 29 of Set 12 | krasnyy chikoy
# Processing Record 30 of Set 12 | issa
# Processing Record 31 of Set 12 | maragogi
# Processing Record 32 of Set 12 | alihe
# Processing Record 33 of Set 12 | san carlos de bariloche
# Processing Record 34 of Set 12 | myitkyina
# Processing Record 35 of Set 12 | morant bay
# Processing Record 36 of Set 12 | slavutych
# Processing Record 37 of Set 12 | hare bay
# Processing Record 38 of Set 12 | cam pha
# City not found. Skipping...
# Processing Record 39 of Set 12 | nuevo progreso
# Processing Record 40 of Set 12 | iquique
# Processing Record 41 of Set 12 | necochea
# Processing Record 42 of Set 12 | klaksvik
# Processing Record 43 of Set 12 | jonuta
# Processing Record 44 of Set 12 | hollabrunn
# Processing Record 45 of Set 12 | port hedland
# Processing Record 46 of Set 12 | hailar
# Processing Record 47 of Set 12 | chodziez
# Processing Record 48 of Set 12 | dunedin
# Processing Record 49 of Set 12 | cap malheureux
# Processing Record 50 of Set 12 | pichayevo
# Processing Record 1 of Set 13 | nenjiang
# Processing Record 2 of Set 13 | ayan
# Processing Record 3 of Set 13 | kaitangata
# Processing Record 4 of Set 13 | aasiaat
# Processing Record 5 of Set 13 | atherton
# Processing Record 6 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 7 of Set 13 | gorontalo
# Processing Record 8 of Set 13 | ayagoz
# Processing Record 9 of Set 13 | san luis
# Processing Record 10 of Set 13 | kabare
# Processing Record 11 of Set 13 | vredendal
# Processing Record 12 of Set 13 | pomabamba
# Processing Record 13 of Set 13 | kyzyl-mazhalyk
# Processing Record 14 of Set 13 | sola
# Processing Record 15 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 16 of Set 13 | horta
# Processing Record 17 of Set 13 | kachikau
# City not found. Skipping...
# Processing Record 18 of Set 13 | cururupu
# Processing Record 19 of Set 13 | vera cruz
# Processing Record 20 of Set 13 | berezovyy
# Processing Record 21 of Set 13 | katangli
# Processing Record 22 of Set 13 | waitati
# Processing Record 23 of Set 13 | chaohu
# Processing Record 24 of Set 13 | damara
# Processing Record 25 of Set 13 | amursk
# Processing Record 26 of Set 13 | mirina
# City not found. Skipping...
# Processing Record 27 of Set 13 | shangrao
# Processing Record 28 of Set 13 | prudentopolis
# Processing Record 29 of Set 13 | havoysund
# Processing Record 30 of Set 13 | sivas
# Processing Record 31 of Set 13 | onguday
# Processing Record 32 of Set 13 | debre tabor
# Processing Record 33 of Set 13 | matata
# Processing Record 34 of Set 13 | seydi
# Processing Record 35 of Set 13 | mecca
# Processing Record 36 of Set 13 | glushkovo
# Processing Record 37 of Set 13 | uige
# Processing Record 38 of Set 13 | talakan
# Processing Record 39 of Set 13 | huron
# Processing Record 40 of Set 13 | manzil jamil
# City not found. Skipping...
# Processing Record 41 of Set 13 | bani
# Processing Record 42 of Set 13 | korla
# Processing Record 43 of Set 13 | ballarat
# Processing Record 44 of Set 13 | yandyki
# Processing Record 45 of Set 13 | awjilah
# Processing Record 46 of Set 13 | dongsheng
# Processing Record 47 of Set 13 | caravelas
# Processing Record 48 of Set 13 | victor harbor
# Processing Record 49 of Set 13 | novo cruzeiro
# Processing Record 50 of Set 13 | weymouth
# Processing Record 1 of Set 14 | mogok
# Processing Record 2 of Set 14 | yantikovo
# Processing Record 3 of Set 14 | dali
# Processing Record 4 of Set 14 | qui nhon
# Processing Record 5 of Set 14 | griffith
# Processing Record 6 of Set 14 | brae
# Processing Record 7 of Set 14 | sindand
# City not found. Skipping...
# Processing Record 8 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 9 of Set 14 | ginir
# Processing Record 10 of Set 14 | alghero
# Processing Record 11 of Set 14 | marawi
# Processing Record 12 of Set 14 | spas-demensk
# Processing Record 13 of Set 14 | chupei
# City not found. Skipping...
# Processing Record 14 of Set 14 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 15 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 14 | iqaluit
# Processing Record 17 of Set 14 | joutseno
# Processing Record 18 of Set 14 | vilhena
# Processing Record 19 of Set 14 | gamba
# Processing Record 20 of Set 14 | vila
# Processing Record 21 of Set 14 | doha
# Processing Record 22 of Set 14 | peace river
# Processing Record 23 of Set 14 | beloha
# Processing Record 24 of Set 14 | fairbanks
# Processing Record 25 of Set 14 | centralia
# Processing Record 26 of Set 14 | kaeo
# Processing Record 27 of Set 14 | melo
# Processing Record 28 of Set 14 | mildura
# Processing Record 29 of Set 14 | kenai
# Processing Record 30 of Set 14 | uyuni
# Processing Record 31 of Set 14 | smolenka
# Processing Record 32 of Set 14 | hakkari
# Processing Record 33 of Set 14 | praia
# Processing Record 34 of Set 14 | fort nelson
# Processing Record 35 of Set 14 | papara
# Processing Record 36 of Set 14 | chililabombwe
# Processing Record 37 of Set 14 | savinka
# Processing Record 38 of Set 14 | luanda
# Processing Record 39 of Set 14 | ardakan
# Processing Record 40 of Set 14 | pinar del rio
# Processing Record 41 of Set 14 | mount darwin
# Processing Record 42 of Set 14 | mankera
# Processing Record 43 of Set 14 | aylmer
# Processing Record 44 of Set 14 | riberalta
# Processing Record 45 of Set 14 | ewo
# Processing Record 46 of Set 14 | port moresby
# Processing Record 47 of Set 14 | kjollefjord
# Processing Record 48 of Set 14 | maniitsoq
# Processing Record 49 of Set 14 | ipswich
# Processing Record 50 of Set 14 | lago da pedra
# Processing Record 1 of Set 15 | big spring
# Processing Record 2 of Set 15 | narrabri
# Processing Record 3 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 4 of Set 15 | hokitika
# Processing Record 5 of Set 15 | pimentel
# Processing Record 6 of Set 15 | gambissara
# Processing Record 7 of Set 15 | wairoa
# Processing Record 8 of Set 15 | eldorado
# Processing Record 9 of Set 15 | colares
# Processing Record 10 of Set 15 | watsa
# Processing Record 11 of Set 15 | mayahi
# Processing Record 12 of Set 15 | ambon
# Processing Record 13 of Set 15 | katha
# City not found. Skipping...
# Processing Record 14 of Set 15 | waipawa
# Processing Record 15 of Set 15 | roald
# Processing Record 16 of Set 15 | saint anthony
# Processing Record 17 of Set 15 | le port
# Processing Record 18 of Set 15 | kisangani
# Processing Record 19 of Set 15 | gidam
# Processing Record 20 of Set 15 | muzhi
# Processing Record 21 of Set 15 | oksfjord
# Processing Record 22 of Set 15 | havre-saint-pierre
# Processing Record 23 of Set 15 | buchanan
# Processing Record 24 of Set 15 | matagami
# Processing Record 25 of Set 15 | pangkalanbuun
# Processing Record 26 of Set 15 | ulkan
# Processing Record 27 of Set 15 | liverpool
# Processing Record 28 of Set 15 | komsomolskiy
# Processing Record 29 of Set 15 | evensk
# Processing Record 30 of Set 15 | kazanka
# Processing Record 31 of Set 15 | vung tau
# Processing Record 32 of Set 15 | gizo
# Processing Record 33 of Set 15 | bosaso
# Processing Record 34 of Set 15 | sohag
# Processing Record 35 of Set 15 | winchester
# Processing Record 36 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 37 of Set 15 | folldal
# Processing Record 38 of Set 15 | ivnya
# Processing Record 39 of Set 15 | abalak
# Processing Record 40 of Set 15 | hofn
# Processing Record 41 of Set 15 | verkhnyaya inta
# Processing Record 42 of Set 15 | rocha
# Processing Record 43 of Set 15 | parangan
# Processing Record 44 of Set 15 | huarmey
# Processing Record 45 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 46 of Set 15 | mwinilunga
# Processing Record 47 of Set 15 | kasongo-lunda
# Processing Record 48 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 15 | trstena
# Processing Record 50 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 1 of Set 16 | santa lucia
# Processing Record 2 of Set 16 | warwick
# Processing Record 3 of Set 16 | murchison
# Processing Record 4 of Set 16 | sakata
# Processing Record 5 of Set 16 | sao joao de pirabas
# Processing Record 6 of Set 16 | panlaitan
# Processing Record 7 of Set 16 | kolondieba
# Processing Record 8 of Set 16 | marzuq
# Processing Record 9 of Set 16 | taganak
# Processing Record 10 of Set 16 | olga
# Processing Record 11 of Set 16 | yatou
# Processing Record 12 of Set 16 | teahupoo
# Processing Record 13 of Set 16 | caldwell
# Processing Record 14 of Set 16 | quatre cocos
# Processing Record 15 of Set 16 | calvinia
# Processing Record 16 of Set 16 | utiroa
# City not found. Skipping...
# Processing Record 17 of Set 16 | kharp
# Processing Record 18 of Set 16 | mandera
# Processing Record 19 of Set 16 | caranavi
# Processing Record 20 of Set 16 | bilibino
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 706

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Hermanus      ZA -34.4187   19.2345     53.37        61
# 1                 Albany      US  42.6001  -73.9662     70.66        85
# 2              Busselton      AU -33.6500  115.3333     61.05        61
# 3          Haverfordwest      GB  51.8017   -4.9691     66.16        92
# 4              Thinadhoo      MV   0.5333   72.9333     83.37        72
# 5               Benguela      AO -12.5763   13.4055     69.24        80
# 6                Rikitea      PF -23.1203 -134.9692     72.59        70
# 7               Tasiilaq      GL  65.6145  -37.6368     37.13        75
# 8  Verkhnyaya Maksakovka      RU  61.6350   50.9674     71.62        68
# 9                Ushuaia      AR -54.8000  -68.3000     29.86        86
#
#    Cloudiness  Wind Speed Current Description
# 0          10        5.99           clear sky
# 1         100        2.44     overcast clouds
# 2          31        6.31    scattered clouds
# 3           0        4.27           clear sky
# 4          10        8.95           clear sky
# 5           8        5.84           clear sky
# 6           1        7.25           clear sky
# 7           1        7.96           clear sky
# 8           0        4.47           clear sky
# 9           0        8.05           clear sky

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
